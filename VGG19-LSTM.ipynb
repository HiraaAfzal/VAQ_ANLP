# %% [markdown]
# #### all imports

# %%
import tensorflow as tf
import os
import numpy as np
import json
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Embedding, LSTM, Dense, Dropout, concatenate
from keras.models import Model
from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import re
import pickle
# Out:
# 2024-06-26 15:22:27.676602: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-26 15:22:27.804729: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-26 15:22:28.391884: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 15:22:28.391965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 15:22:28.517709: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-26 15:22:28.774979: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-26 15:22:28.777879: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 15:22:30.153271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### read all dataset questions and answers from json files

# %%
train_file_questions = 'datasets/v2_OpenEnded_mscoco_train2014_questions.json'
train_file_annotations = 'datasets/v2_mscoco_train2014_annotations.json'
val_file_questions = 'datasets/v2_OpenEnded_mscoco_val2014_questions.json'
val_file_annotations = 'datasets/v2_mscoco_val2014_annotations.json'
test_file_questions = 'datasets/v2_OpenEnded_mscoco_test2015_questions.json'


with open(train_file_questions, 'r') as f:
    train_questions = json.load(f)['questions']
    f.close()

with open(train_file_annotations, 'r') as f:
    train_annotations = json.load(f)['annotations']
    f.close()

with open(val_file_questions, 'r') as f:
    val_questions = json.load(f)['questions']
    f.close()

with open(val_file_annotations, 'r') as f:
    val_annotations = json.load(f)['annotations']
    f.close()

#with open(test_file_questions, 'r') as f:
#    test_questions = json.load(f)['questions']
#    f.close()

# %% [markdown]
# #### read all train and validate image features extracted by VGG19 with IDs from the pkl files

# %%
# Read dictionary pkl file
with open('vgg19_train_data.pkl', 'rb') as fp:
    train_imgs_features = pickle.load(fp)
    print('successful')
# Read dictionary pkl file
with open('vgg19_val_data.pkl', 'rb') as fp:
    val_imgs_features = pickle.load(fp)
    print('successful')
# Out:
# successful
# successful

# %% [markdown]
# #### append validate to train features

# %%
train_imgs_features.update(val_imgs_features)

# %%
len(train_imgs_features)
# Out:
# 123287

# %% [markdown]
# #### append validate questions and answers to train questions and answers

# %%
# # Combine the training and validation questions and annotations
train_questions = val_questions
train_annotations = val_annotations

# %% [markdown]
# #### encode questions and answers, and create image features list

# %%
del val_questions
del val_annotations
del val_imgs_features

# %%
# Extract the questions and answers
questions = []
answers = []
features_id = []

for i in range(len(train_questions)):
    questions.append(train_questions[i]['question'])
    answers.append(train_annotations[i]['multiple_choice_answer'])
    features_id.append(train_questions[i]["image_id"])


del train_questions
del train_annotations

# Tokenize the questions
tokenizer = Tokenizer()
tokenizer.fit_on_texts(questions)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(questions)

del questions
del tokenizer

max_question_length = 30
padded_sequences = pad_sequences(sequences, maxlen=max_question_length)

del sequences

# Convert the answers to one-hot vectors
answers_tokenizer = Tokenizer()
answers_tokenizer.fit_on_texts(answers)
answer_word_index = answers_tokenizer.word_index
num_classes = len(answer_word_index)
answer_sequences = answers_tokenizer.texts_to_sequences(answers)


del answers_tokenizer

# Pad the answer sequences to ensure they all have the same length
max_answer_length = max(len(seq) for seq in answer_sequences)
padded_answers = pad_sequences(answer_sequences, maxlen=max_answer_length)

# Get the unique answers in the dataset and create a dictionary to map them to integer labels
unique_answers = list(set(answers))
label_map = {answer: i for i, answer in enumerate(unique_answers)}

del answer_sequences

# Convert the answers to integer labels and then to one-hot vectors
labels = [label_map[answer] for answer in answers]
one_hot_answers = to_categorical(labels, num_classes=len(unique_answers))

# %%
unique_answers
# Out:
# ['under elephant',
#  'air freshener',
#  'public market',
#  'looking at cell phone',
#  'keep calm',
#  'content',
#  '70 inch',
#  'in case',
#  'pan is hot',
#  'he is tall',
#  'man in orange',
#  'female impersonators',
#  'paperwork',
#  'no dress',
#  'maine',
#  'huge',
#  'elmira',
#  'seed',
#  'cleveland',
#  'couple',
#  'butt cheek',
#  'kicking',
#  'grace',
#  'not ripe',
#  'east 34th st',
#  'holding bat',
#  'family',
#  'brownie',
#  'haight and ashbury',
#  'towel hook',
#  'destin, fl',
#  'greenhouse',
#  'black and white flowers',
#  'denim',
#  'catch frisbee',
#  'mallet',
#  'skateboard man',
#  'fettuccine',
#  'nightstand',
#  'esda',
#  '530264',
#  'black/silver',
#  'button',
#  'not there',
#  '200',
#  'doughnut shop',
#  'badminton',
#  'helping her up',
#  'hot dog menu',
#  'monkeys',
#  'narrowing road',
#  'casserole',
#  'behind meters',
#  'easton',
#  'doug schaefer',
#  'mk home',
#  'semi',
#  'front of computer',
#  'one playing game; other holding hands together',
#  'cut them up',
#  'father and daughter',
#  'hurricane',
#  'baseball glove',
#  'grass',
#  'rolling pin',
#  'icing',
#  '5199',
#  '1:20',
#  'dane101',
#  'bnmghjyui',
#  'singapore',
#  'salad and sandwich',
#  'wikipedia',
#  'train station',
#  'torn',
#  'above train',
#  'blowing out candles',
#  'getting ready to hit ball',
#  'screen',
#  'stanley cup champions',
#  'bicycle tire',
#  'rubber',
#  'left turn watch for pedestrians',
#  'perching',
#  'holding napkin',
#  'tamales mi lupita',
#  'italian',
#  'public parking',
#  'angled',
#  'business luncheon',
#  'january 2010',
#  'business professionals',
#  'she wants to win',
#  'no bridge',
#  'hawaii',
#  'front ave and seventh st',
#  'medium high',
#  'with knife',
#  'birthday',
#  'suv',
#  'berlin',
#  'covidien',
#  '326',
#  'selling food',
#  'one in front',
#  'to hit ball',
#  'bowling alley',
#  'beers reserve space',
#  '11:10',
#  'lifting',
#  'cub',
#  'emile swain',
#  'black orange',
#  '6 hours 40 minutes',
#  'spinach',
#  'college students',
#  'show off',
#  'dish rack',
#  'naked',
#  'silver and green',
#  'wrap',
#  '29',
#  'black and yellow',
#  'id card',
#  'pottsville',
#  'catch frog',
#  'milledge',
#  'android',
#  'jacket on right',
#  'paddle boards',
#  'moo',
#  'holly',
#  'early bird',
#  'scrapbook',
#  'blue sky',
#  'burbank station',
#  'relieving',
#  'white team',
#  'pulling cart',
#  'hitting one back',
#  'diagonal',
#  'paper doilies',
#  'being pet',
#  'question your government',
#  'no chairs',
#  'tv screen',
#  '12:47',
#  'long life',
#  'boulogne',
#  'increased',
#  'inn by bay',
#  'kwik e mart',
#  'tuxedo cat',
#  'circles',
#  'cafe huong que',
#  'award',
#  'illegible',
#  'two women, cartoon',
#  'lake michigan',
#  'phone game',
#  'under bike',
#  'capitalism',
#  'radio city',
#  'rice',
#  'hats',
#  'avocado, ginger',
#  '1257',
#  'drawings',
#  'have you paid parking meter',
#  'neath',
#  '5 feet',
#  's48',
#  'laces',
#  'dining',
#  'beagles',
#  'coffee shop',
#  'lodge',
#  'in baseball field',
#  'tabrez bagwan',
#  'kirk douglas way',
#  'msn hd',
#  'weimaraner',
#  'under chair',
#  'bagel',
#  'britex',
#  'silverware',
#  '7:52',
#  'tank',
#  '3456',
#  'black, red, tan, white',
#  '14.99',
#  'pretoria',
#  'hero',
#  'air conditioner',
#  'floods',
#  'nikon and xfinity',
#  'meeting',
#  'day',
#  'barbecue sauce',
#  'left hand',
#  '300 pounds',
#  'eating cake',
#  'pool',
#  "fatso's",
#  'tortillas',
#  'uneven',
#  'peddling',
#  'i love you',
#  'violin',
#  'long sleeves',
#  'splashdogs.com',
#  'on top of desk',
#  'qwerty',
#  '480',
#  'seinfeld',
#  'sp-yyy',
#  'ketchup and mustard',
#  'blue and green',
#  'baptist',
#  'wraps',
#  'large',
#  '473',
#  'life is good',
#  'third buy from left',
#  'orange and donut',
#  'bunny',
#  '4:47',
#  'jazz',
#  'it is mom',
#  'there is no cup',
#  '34',
#  'warning for pedestrian',
#  'hydrant is spraying water',
#  'urinate',
#  'ahead',
#  'ghost',
#  'sausages',
#  'doors open',
#  'coffee hound',
#  'elastic',
#  'morgan rd',
#  '4:20',
#  'bx-df-45',
#  'lochs',
#  'tall',
#  'black, yellow, red, & blue',
#  'on parking meter',
#  'court diner',
#  'both dogs',
#  'back by windows',
#  '20 26',
#  '8158',
#  'merrick',
#  'iron',
#  'wb mason',
#  'neighborhood',
#  'cauliflower',
#  'only girl',
#  'boathouse',
#  '99e',
#  'iced tea',
#  'unisex',
#  'great western',
#  'skate surfing',
#  'gingham',
#  'henry st and love la',
#  'plymouth in your pocket',
#  'kickstands',
#  "jenny's",
#  'surfboards',
#  'tisores pells',
#  'arabic',
#  'pooping',
#  'bag',
#  'suzuki',
#  'flats',
#  'rossignol',
#  "bicycles don't need them",
#  'electricity',
#  'birks',
#  'clown',
#  'asus',
#  'cheetah',
#  '3:50',
#  'sports car',
#  'brown palace',
#  'objects in mirror are closer than they appear',
#  'dinosaur',
#  'no bear',
#  'in front of shelves',
#  'pillsbury doughboy',
#  "it's jet propelled",
#  'in field',
#  'sun',
#  'v neck and jeans',
#  'rose',
#  'dusk',
#  "there aren't",
#  'baggage claim',
#  'alive',
#  'on finger',
#  'baby food',
#  'cd player',
#  'no one is using them',
#  'quiet',
#  '88',
#  'electronics',
#  'heads',
#  'closer one',
#  'under clock',
#  '5:39',
#  "in girl's hand",
#  'nkoba',
#  'merry go round',
#  'hashi sushi',
#  'phone booth',
#  'guy in middle with foot on ball',
#  'printer',
#  'rug doctor',
#  'multi colored',
#  'bread and meat',
#  'looking outside',
#  '@#!!',
#  'r',
#  'behind building',
#  'it will play',
#  '1 cup',
#  'business',
#  'uncovered',
#  'under microwave',
#  'crt',
#  '1 on left',
#  'mound',
#  '75 feet',
#  'labs',
#  'dessert',
#  'not old',
#  'jack kerouac',
#  '30-36',
#  'flamingo',
#  'wheelbarrow',
#  'comedy central',
#  'in litter box',
#  'thin crust',
#  'practice',
#  'nowhere',
#  'juicy juice',
#  'hilton dew lakes',
#  'under him',
#  'assorted',
#  'on edge',
#  'jeep',
#  '24 hour',
#  'eating hot dog',
#  'sltb',
#  'other boy',
#  '477',
#  'platter',
#  'snack',
#  "banana's,orange's",
#  '180',
#  'nsp',
#  'one world',
#  'northwest christian schools',
#  'eyes closed',
#  'airplane wing',
#  'denver broncos',
#  'robot',
#  '1 and 1',
#  'markham and president clinton',
#  'carmelli',
#  'mario',
#  'rock racing',
#  'board',
#  'same color',
#  'no',
#  'port river dolphin cruises',
#  'zeitgeist',
#  'stripe',
#  'patriots',
#  '6-10',
#  'opened',
#  'wwwchoufanicom',
#  'mallard',
#  '763',
#  'ladybug',
#  'green yellow and purple',
#  'laser',
#  'pattern',
#  'contact solution',
#  'carving pumpkins',
#  'visors',
#  'watch movies',
#  'attentive',
#  'magazine',
#  'bird bath',
#  '108',
#  'medicine',
#  'south common center',
#  'scores',
#  'diamond',
#  'spinning around bat',
#  'blue cheese',
#  'baseball uniform',
#  '9:25',
#  'to dry',
#  'm552bci',
#  'cotehill',
#  'flatbread',
#  'on motorcycle',
#  'backpacks',
#  '141',
#  'fried',
#  'on track',
#  'link',
#  'tunnel',
#  'ones on right',
#  'hot dogs',
#  'judges',
#  'carriage',
#  'snowboarding',
#  'bench',
#  '279',
#  'doily',
#  '70s',
#  'bs',
#  'heritage express',
#  '10:33',
#  'born that way',
#  'horizontal',
#  'doyers st',
#  'to stop fires',
#  'lift',
#  'columns',
#  'necklace',
#  'toothbrush holder',
#  'queens blvd',
#  'railing',
#  'ones on left',
#  'above bathtub',
#  'chapel st',
#  'both giraffes',
#  'uncovering tv',
#  'easy st',
#  'vodka',
#  "he's hot",
#  'chlorine strafe',
#  'cut himself',
#  'fmk',
#  'swiss army',
#  "woman's arms",
#  'serving cake',
#  'night time',
#  'garry wilmore',
#  'be prepared to stop',
#  'bcbg',
#  'cellular telephone',
#  'oe188',
#  'clasping',
#  'floss',
#  'braided',
#  'standing on platform',
#  'crystals',
#  'pro tec',
#  "i don't",
#  'beef and peppers',
#  'vent',
#  'later',
#  'pearl',
#  'not much',
#  'do not enter',
#  'pottery store',
#  'orange/yellow plaid',
#  '2:03',
#  'deere',
#  'wta',
#  'on his knee',
#  'skulls',
#  'manchester',
#  'leaving',
#  'sf weekly',
#  'in pen',
#  'smelling wine',
#  'jordan',
#  'beer bottle',
#  'vultures',
#  'actor',
#  "pj's",
#  'schaffhauser platz',
#  "joe's",
#  'glowing',
#  'motorcycle and car',
#  'closer',
#  'bus',
#  'cola',
#  'detour',
#  'feeding giraffes',
#  'rice, meat, vegetables',
#  'hit it',
#  'blackwell',
#  'comfy',
#  'visalia',
#  'around car',
#  'fm11',
#  'girl in yellow dress',
#  'track 1',
#  'qa',
#  'tigo',
#  '12:17',
#  'big beaked',
#  'devil rays',
#  'saturated',
#  'half size',
#  "arby's",
#  'to see giraffe',
#  'ocean kayak',
#  'his and hers',
#  'spider',
#  'pedestrian zone',
#  '80',
#  'firemen',
#  'no clouds',
#  '12:03',
#  'charging',
#  'strawberry and banana',
#  'hollywood blvd',
#  'in trees',
#  'man in jersey',
#  'boys',
#  'damian',
#  'bald',
#  'echo st 6200 n',
#  'swim trunks',
#  '6:52',
#  'worker rights',
#  'carnations',
#  'merry christmas',
#  'blue, yellow and green',
#  '7 eleven',
#  'biodiesel',
#  '65745',
#  'for lease',
#  'laptop',
#  'warning',
#  'pier 30',
#  'at back of photo',
#  'road bike',
#  'rein',
#  'ipod',
#  'above sink',
#  'in front of him',
#  '550',
#  "he's losing",
#  'fanta',
#  'sit',
#  'leather jacket',
#  'weighing',
#  'for',
#  'unanswerable',
#  'black, brown and white',
#  'cardinals',
#  "smucker's",
#  'mosque',
#  'escalator',
#  'afflelou',
#  'on bookcase',
#  'scrunchies',
#  'patient',
#  '1369',
#  'road trip',
#  'bossini',
#  'pay to park',
#  'towel',
#  'behind couch',
#  'oxen',
#  'dogs',
#  'end',
#  'in cage',
#  'gas mask',
#  'she grew it',
#  '8:10',
#  'reays',
#  'banana',
#  'candle',
#  'motta',
#  'crowns',
#  'prius',
#  'on cart',
#  'stand behind',
#  'essay',
#  'to keep it from running away',
#  'below mantle',
#  'n567 jvv',
#  'baa',
#  'fresh berries',
#  'ear of elephant',
#  '1:03',
#  'indian style',
#  'linen',
#  'harvesting',
#  'behind toilet',
#  'ott 98',
#  'looking at camera',
#  'cracker',
#  'yoga mat',
#  'letom',
#  'manners street',
#  'advent',
#  'william',
#  'putting on shoe',
#  '19:11',
#  'cornell',
#  'north',
#  'f',
#  'golf',
#  'dishwasher',
#  'top shelf',
#  'wifi',
#  'fly away',
#  'yard',
#  'pen and glasses',
#  'vintage',
#  'mowing',
#  'you 551',
#  'bearded man',
#  'ytl 434',
#  'not very',
#  'san mateo',
#  'limited visibility',
#  'hard',
#  'behind catcher',
#  'to put out fires',
#  'parking sign',
#  'chris perkins',
#  'howard',
#  'beret',
#  "weiner you've got to be sitting me",
#  'listening to announcer',
#  'storm coming',
#  'yellow blue',
#  'different vehicles',
#  'fsg',
#  'shabby genteel',
#  '9.99',
#  'roman numerals',
#  '1306',
#  'in rows',
#  'satellite dish',
#  'solids',
#  'w center st',
#  'sf weekly free every wednesday',
#  'eb',
#  'bicycle',
#  'bohemiantraveler.com',
#  'by toilet',
#  '2:26',
#  'monitor on',
#  'dog frisbee competition',
#  'sheep barn',
#  'signs',
#  'august 27',
#  'bleach',
#  'behind boy',
#  'cannot tell',
#  'less',
#  'nonstick',
#  'truck bed',
#  'no text',
#  'extra cheese',
#  'heat food',
#  'cairn',
#  'crowded',
#  'anza',
#  'nationals',
#  'landed',
#  'ipad, laptop, and cell phone',
#  'hanging on oven',
#  'slower',
#  'wedge',
#  'not high',
#  'faconnable',
#  'mango',
#  'staring',
#  'no belt',
#  'visilab',
#  'china',
#  'gt',
#  'bulls',
#  'last week',
#  'brabantliner',
#  'bicycle tires',
#  'union pacific',
#  'colin',
#  '4:32',
#  '5pm',
#  'scratches',
#  'soccer balls',
#  'willard',
#  'raffaello',
#  'holding umbrella',
#  'handshake',
#  'santa hats',
#  'phone and lighter',
#  'maze',
#  'steak sauce',
#  'albert s samuels co',
#  'flip flops',
#  '4:04',
#  'bellhop',
#  'looking at horses',
#  'nokia',
#  '1st person',
#  'yorkie',
#  'palm trees, surfboards, banner',
#  'to watch game',
#  '1:41',
#  'countertops',
#  'kmb',
#  'lion and hedgehog',
#  'motorcycle racing',
#  'under leg',
#  'quail',
#  'lily pads',
#  '2990',
#  'rocking',
#  'recreation',
#  'mixed',
#  'lollipop',
#  'african',
#  'bird feeder',
#  '150',
#  'no bag',
#  'measuring distance',
#  'on them',
#  'dyed it',
#  'daffodils',
#  'f-150',
#  'stop and one way',
#  'rod',
#  'rt',
#  'baseball cap',
#  'new orleans',
#  'pen',
#  'resident evil',
#  'grow',
#  'sneaker',
#  '3:15',
#  'top ramen',
#  'white, brown, black',
#  'apple, banana, pomegranate',
#  'buggy',
#  '7577',
#  'for display',
#  'other dog',
#  'iced coffee',
#  'plug',
#  'adams',
#  'neither',
#  'sleeping bag',
#  'cafeteria',
#  'chained',
#  'festival',
#  '631',
#  'sewing',
#  'boots and umbrella',
#  'easter',
#  'bed',
#  'spa',
#  '987',
#  'passenger train station',
#  '100 feet',
#  'longhorns',
#  '296',
#  'books',
#  'ferris wheel',
#  "women's",
#  'strapless',
#  '11:33',
#  'vehicle',
#  'chess piece',
#  'its out for trash',
#  'nashville',
#  'zero',
#  '2:05',
#  'wtatennis.com',
#  '6"',
#  'other man',
#  'ywl 45v',
#  'calvin klein',
#  'no letters',
#  'britvic',
#  'peace sign',
#  '3:48',
#  'showing videos',
#  '2:39',
#  'manly',
#  '402b',
#  '24"',
#  'john d',
#  'cooking',
#  'purple, yellow, white, brown, green, red, orange, yellow, blue',
#  'kia',
#  'between glass',
#  'they are decorated',
#  '650dye',
#  'on top of toilet',
#  '70677',
#  'dreadlocks',
#  'bumper',
#  '9:17',
#  'blue angels',
#  'city coach',
#  'yard sale',
#  'eldest',
#  'mount pleasant rd',
#  'ficus',
#  'whiskey',
#  'column',
#  'nightfall',
#  'latin',
#  'white, black, red',
#  'paddle boat',
#  'john b clarke',
#  'squat',
#  'patch',
#  "it's time to siena",
#  'shades',
#  'behind man to left',
#  'pointy',
#  'hills',
#  'ikea',
#  'nasa ames',
#  'northumbria',
#  'aegon',
#  'basket',
#  'boy on right',
#  '1:05',
#  'bridgestone',
#  'point',
#  'tractor trailer',
#  'overpass',
#  'wallpaper',
#  'on rock',
#  'ones fighter jet',
#  'holding umbrellas',
#  'it is paved',
#  'watching presentation',
#  'nervous',
#  'vapor',
#  'bryn mawr',
#  '4:49',
#  'competing',
#  'cruise ship',
#  'veterinarian',
#  'ukrsibbank',
#  'fruit and cheese',
#  '1:08',
#  'tank top and shorts',
#  'nottingham',
#  '1998',
#  'curtain',
#  'hickory dickory dock',
#  'fishnet',
#  'catnip',
#  'bunches',
#  'next to wall',
#  'ap',
#  'pepsi cola',
#  'dress shirt',
#  'mavic',
#  'very clear',
#  '554',
#  '44019',
#  'tile',
#  'play games',
#  'guiding horse',
#  'chair',
#  'circular',
#  'talk',
#  'pepperoni',
#  "he can't walk",
#  'hot dog and fries',
#  'us open',
#  'avocado',
#  'reins',
#  'palomino',
#  'right hand',
#  'not busy',
#  'face',
#  'attic',
#  'turnover',
#  'bowls',
#  'no closet',
#  'west union',
#  'west coast air',
#  'electric vehicle parking only while charging',
#  'second from left',
#  'shoulders',
#  'handmade nation',
#  'under pillow',
#  'placemats',
#  'speed rabbit pizza',
#  'no smoking sign',
#  'in front of boxes',
#  'puddles',
#  'pj 2009',
#  'cauliflower and broccoli',
#  'easel',
#  'cardinal male',
#  '$10',
#  'in hand',
#  'eye protection',
#  'charlotte',
#  "ray's tavern",
#  '39, 1',
#  'they are fried',
#  'bent',
#  'mini golf',
#  'on vase',
#  'zombie',
#  'macaroni salad',
#  'thermostat',
#  '200 feet',
#  'legs crossed',
#  'shipyard',
#  'houseboats',
#  'chair, wii remote, tv remotes',
#  'wednesday',
#  'watching ocean',
#  'cubs',
#  'portrait',
#  'lower manhattan',
#  'leftmost',
#  'bundt',
#  'atlantic',
#  'very long',
#  'desk job',
#  'by wall',
#  'lifeguard stand',
#  'in water',
#  'ariel',
#  'swinging bat',
#  '2:55',
#  'to food',
#  'sitting in bowl',
#  '1406',
#  'rocking chair',
#  'bikini',
#  'in his hands',
#  'tomato, cheese, onion',
#  'dsb',
#  'end of school',
#  'it is dark out',
#  'children love them',
#  'mitt',
#  '4:35',
#  'pete rose',
#  'pure white',
#  'brazil',
#  'trim',
#  '4 to 5',
#  'troll',
#  'street names',
#  'horses, cows',
#  'getting her hair done',
#  '7:00',
#  'mat',
#  'waiting to hit',
#  'lorac',
#  'stop think observe proceed',
#  'chiclets',
#  'next to fire hydrant',
#  'prof verbernelaan',
#  'last',
#  'c92678m',
#  'apartment',
#  'geico',
#  'brewer',
#  'oregon',
#  'purple and green',
#  "chef's",
#  'baseballs',
#  'blue plaid',
#  'dockers',
#  'pillars',
#  'seat cover',
#  'medemblik bus station',
#  'shaking camera',
#  'shingles',
#  'white shirt',
#  'baseball bats',
#  'in forest',
#  'white yellow pink purple and blue',
#  'sortie',
#  'wet grass',
#  'junkyard',
#  '44',
#  'lawn',
#  'bear and wolf museum',
#  'selfie stick',
#  ...]

# %%
label_map
# Out:
# {'under elephant': 0,
#  'air freshener': 1,
#  'public market': 2,
#  'looking at cell phone': 3,
#  'keep calm': 4,
#  'content': 5,
#  '70 inch': 6,
#  'in case': 7,
#  'pan is hot': 8,
#  'he is tall': 9,
#  'man in orange': 10,
#  'female impersonators': 11,
#  'paperwork': 12,
#  'no dress': 13,
#  'maine': 14,
#  'huge': 15,
#  'elmira': 16,
#  'seed': 17,
#  'cleveland': 18,
#  'couple': 19,
#  'butt cheek': 20,
#  'kicking': 21,
#  'grace': 22,
#  'not ripe': 23,
#  'east 34th st': 24,
#  'holding bat': 25,
#  'family': 26,
#  'brownie': 27,
#  'haight and ashbury': 28,
#  'towel hook': 29,
#  'destin, fl': 30,
#  'greenhouse': 31,
#  'black and white flowers': 32,
#  'denim': 33,
#  'catch frisbee': 34,
#  'mallet': 35,
#  'skateboard man': 36,
#  'fettuccine': 37,
#  'nightstand': 38,
#  'esda': 39,
#  '530264': 40,
#  'black/silver': 41,
#  'button': 42,
#  'not there': 43,
#  '200': 44,
#  'doughnut shop': 45,
#  'badminton': 46,
#  'helping her up': 47,
#  'hot dog menu': 48,
#  'monkeys': 49,
#  'narrowing road': 50,
#  'casserole': 51,
#  'behind meters': 52,
#  'easton': 53,
#  'doug schaefer': 54,
#  'mk home': 55,
#  'semi': 56,
#  'front of computer': 57,
#  'one playing game; other holding hands together': 58,
#  'cut them up': 59,
#  'father and daughter': 60,
#  'hurricane': 61,
#  'baseball glove': 62,
#  'grass': 63,
#  'rolling pin': 64,
#  'icing': 65,
#  '5199': 66,
#  '1:20': 67,
#  'dane101': 68,
#  'bnmghjyui': 69,
#  'singapore': 70,
#  'salad and sandwich': 71,
#  'wikipedia': 72,
#  'train station': 73,
#  'torn': 74,
#  'above train': 75,
#  'blowing out candles': 76,
#  'getting ready to hit ball': 77,
#  'screen': 78,
#  'stanley cup champions': 79,
#  'bicycle tire': 80,
#  'rubber': 81,
#  'left turn watch for pedestrians': 82,
#  'perching': 83,
#  'holding napkin': 84,
#  'tamales mi lupita': 85,
#  'italian': 86,
#  'public parking': 87,
#  'angled': 88,
#  'business luncheon': 89,
#  'january 2010': 90,
#  'business professionals': 91,
#  'she wants to win': 92,
#  'no bridge': 93,
#  'hawaii': 94,
#  'front ave and seventh st': 95,
#  'medium high': 96,
#  'with knife': 97,
#  'birthday': 98,
#  'suv': 99,
#  'berlin': 100,
#  'covidien': 101,
#  '326': 102,
#  'selling food': 103,
#  'one in front': 104,
#  'to hit ball': 105,
#  'bowling alley': 106,
#  'beers reserve space': 107,
#  '11:10': 108,
#  'lifting': 109,
#  'cub': 110,
#  'emile swain': 111,
#  'black orange': 112,
#  '6 hours 40 minutes': 113,
#  'spinach': 114,
#  'college students': 115,
#  'show off': 116,
#  'dish rack': 117,
#  'naked': 118,
#  'silver and green': 119,
#  'wrap': 120,
#  '29': 121,
#  'black and yellow': 122,
#  'id card': 123,
#  'pottsville': 124,
#  'catch frog': 125,
#  'milledge': 126,
#  'android': 127,
#  'jacket on right': 128,
#  'paddle boards': 129,
#  'moo': 130,
#  'holly': 131,
#  'early bird': 132,
#  'scrapbook': 133,
#  'blue sky': 134,
#  'burbank station': 135,
#  'relieving': 136,
#  'white team': 137,
#  'pulling cart': 138,
#  'hitting one back': 139,
#  'diagonal': 140,
#  'paper doilies': 141,
#  'being pet': 142,
#  'question your government': 143,
#  'no chairs': 144,
#  'tv screen': 145,
#  '12:47': 146,
#  'long life': 147,
#  'boulogne': 148,
#  'increased': 149,
#  'inn by bay': 150,
#  'kwik e mart': 151,
#  'tuxedo cat': 152,
#  'circles': 153,
#  'cafe huong que': 154,
#  'award': 155,
#  'illegible': 156,
#  'two women, cartoon': 157,
#  'lake michigan': 158,
#  'phone game': 159,
#  'under bike': 160,
#  'capitalism': 161,
#  'radio city': 162,
#  'rice': 163,
#  'hats': 164,
#  'avocado, ginger': 165,
#  '1257': 166,
#  'drawings': 167,
#  'have you paid parking meter': 168,
#  'neath': 169,
#  '5 feet': 170,
#  's48': 171,
#  'laces': 172,
#  'dining': 173,
#  'beagles': 174,
#  'coffee shop': 175,
#  'lodge': 176,
#  'in baseball field': 177,
#  'tabrez bagwan': 178,
#  'kirk douglas way': 179,
#  'msn hd': 180,
#  'weimaraner': 181,
#  'under chair': 182,
#  'bagel': 183,
#  'britex': 184,
#  'silverware': 185,
#  '7:52': 186,
#  'tank': 187,
#  '3456': 188,
#  'black, red, tan, white': 189,
#  '14.99': 190,
#  'pretoria': 191,
#  'hero': 192,
#  'air conditioner': 193,
#  'floods': 194,
#  'nikon and xfinity': 195,
#  'meeting': 196,
#  'day': 197,
#  'barbecue sauce': 198,
#  'left hand': 199,
#  '300 pounds': 200,
#  'eating cake': 201,
#  'pool': 202,
#  "fatso's": 203,
#  'tortillas': 204,
#  'uneven': 205,
#  'peddling': 206,
#  'i love you': 207,
#  'violin': 208,
#  'long sleeves': 209,
#  'splashdogs.com': 210,
#  'on top of desk': 211,
#  'qwerty': 212,
#  '480': 213,
#  'seinfeld': 214,
#  'sp-yyy': 215,
#  'ketchup and mustard': 216,
#  'blue and green': 217,
#  'baptist': 218,
#  'wraps': 219,
#  'large': 220,
#  '473': 221,
#  'life is good': 222,
#  'third buy from left': 223,
#  'orange and donut': 224,
#  'bunny': 225,
#  '4:47': 226,
#  'jazz': 227,
#  'it is mom': 228,
#  'there is no cup': 229,
#  '34': 230,
#  'warning for pedestrian': 231,
#  'hydrant is spraying water': 232,
#  'urinate': 233,
#  'ahead': 234,
#  'ghost': 235,
#  'sausages': 236,
#  'doors open': 237,
#  'coffee hound': 238,
#  'elastic': 239,
#  'morgan rd': 240,
#  '4:20': 241,
#  'bx-df-45': 242,
#  'lochs': 243,
#  'tall': 244,
#  'black, yellow, red, & blue': 245,
#  'on parking meter': 246,
#  'court diner': 247,
#  'both dogs': 248,
#  'back by windows': 249,
#  '20 26': 250,
#  '8158': 251,
#  'merrick': 252,
#  'iron': 253,
#  'wb mason': 254,
#  'neighborhood': 255,
#  'cauliflower': 256,
#  'only girl': 257,
#  'boathouse': 258,
#  '99e': 259,
#  'iced tea': 260,
#  'unisex': 261,
#  'great western': 262,
#  'skate surfing': 263,
#  'gingham': 264,
#  'henry st and love la': 265,
#  'plymouth in your pocket': 266,
#  'kickstands': 267,
#  "jenny's": 268,
#  'surfboards': 269,
#  'tisores pells': 270,
#  'arabic': 271,
#  'pooping': 272,
#  'bag': 273,
#  'suzuki': 274,
#  'flats': 275,
#  'rossignol': 276,
#  "bicycles don't need them": 277,
#  'electricity': 278,
#  'birks': 279,
#  'clown': 280,
#  'asus': 281,
#  'cheetah': 282,
#  '3:50': 283,
#  'sports car': 284,
#  'brown palace': 285,
#  'objects in mirror are closer than they appear': 286,
#  'dinosaur': 287,
#  'no bear': 288,
#  'in front of shelves': 289,
#  'pillsbury doughboy': 290,
#  "it's jet propelled": 291,
#  'in field': 292,
#  'sun': 293,
#  'v neck and jeans': 294,
#  'rose': 295,
#  'dusk': 296,
#  "there aren't": 297,
#  'baggage claim': 298,
#  'alive': 299,
#  'on finger': 300,
#  'baby food': 301,
#  'cd player': 302,
#  'no one is using them': 303,
#  'quiet': 304,
#  '88': 305,
#  'electronics': 306,
#  'heads': 307,
#  'closer one': 308,
#  'under clock': 309,
#  '5:39': 310,
#  "in girl's hand": 311,
#  'nkoba': 312,
#  'merry go round': 313,
#  'hashi sushi': 314,
#  'phone booth': 315,
#  'guy in middle with foot on ball': 316,
#  'printer': 317,
#  'rug doctor': 318,
#  'multi colored': 319,
#  'bread and meat': 320,
#  'looking outside': 321,
#  '@#!!': 322,
#  'r': 323,
#  'behind building': 324,
#  'it will play': 325,
#  '1 cup': 326,
#  'business': 327,
#  'uncovered': 328,
#  'under microwave': 329,
#  'crt': 330,
#  '1 on left': 331,
#  'mound': 332,
#  '75 feet': 333,
#  'labs': 334,
#  'dessert': 335,
#  'not old': 336,
#  'jack kerouac': 337,
#  '30-36': 338,
#  'flamingo': 339,
#  'wheelbarrow': 340,
#  'comedy central': 341,
#  'in litter box': 342,
#  'thin crust': 343,
#  'practice': 344,
#  'nowhere': 345,
#  'juicy juice': 346,
#  'hilton dew lakes': 347,
#  'under him': 348,
#  'assorted': 349,
#  'on edge': 350,
#  'jeep': 351,
#  '24 hour': 352,
#  'eating hot dog': 353,
#  'sltb': 354,
#  'other boy': 355,
#  '477': 356,
#  'platter': 357,
#  'snack': 358,
#  "banana's,orange's": 359,
#  '180': 360,
#  'nsp': 361,
#  'one world': 362,
#  'northwest christian schools': 363,
#  'eyes closed': 364,
#  'airplane wing': 365,
#  'denver broncos': 366,
#  'robot': 367,
#  '1 and 1': 368,
#  'markham and president clinton': 369,
#  'carmelli': 370,
#  'mario': 371,
#  'rock racing': 372,
#  'board': 373,
#  'same color': 374,
#  'no': 375,
#  'port river dolphin cruises': 376,
#  'zeitgeist': 377,
#  'stripe': 378,
#  'patriots': 379,
#  '6-10': 380,
#  'opened': 381,
#  'wwwchoufanicom': 382,
#  'mallard': 383,
#  '763': 384,
#  'ladybug': 385,
#  'green yellow and purple': 386,
#  'laser': 387,
#  'pattern': 388,
#  'contact solution': 389,
#  'carving pumpkins': 390,
#  'visors': 391,
#  'watch movies': 392,
#  'attentive': 393,
#  'magazine': 394,
#  'bird bath': 395,
#  '108': 396,
#  'medicine': 397,
#  'south common center': 398,
#  'scores': 399,
#  'diamond': 400,
#  'spinning around bat': 401,
#  'blue cheese': 402,
#  'baseball uniform': 403,
#  '9:25': 404,
#  'to dry': 405,
#  'm552bci': 406,
#  'cotehill': 407,
#  'flatbread': 408,
#  'on motorcycle': 409,
#  'backpacks': 410,
#  '141': 411,
#  'fried': 412,
#  'on track': 413,
#  'link': 414,
#  'tunnel': 415,
#  'ones on right': 416,
#  'hot dogs': 417,
#  'judges': 418,
#  'carriage': 419,
#  'snowboarding': 420,
#  'bench': 421,
#  '279': 422,
#  'doily': 423,
#  '70s': 424,
#  'bs': 425,
#  'heritage express': 426,
#  '10:33': 427,
#  'born that way': 428,
#  'horizontal': 429,
#  'doyers st': 430,
#  'to stop fires': 431,
#  'lift': 432,
#  'columns': 433,
#  'necklace': 434,
#  'toothbrush holder': 435,
#  'queens blvd': 436,
#  'railing': 437,
#  'ones on left': 438,
#  'above bathtub': 439,
#  'chapel st': 440,
#  'both giraffes': 441,
#  'uncovering tv': 442,
#  'easy st': 443,
#  'vodka': 444,
#  "he's hot": 445,
#  'chlorine strafe': 446,
#  'cut himself': 447,
#  'fmk': 448,
#  'swiss army': 449,
#  "woman's arms": 450,
#  'serving cake': 451,
#  'night time': 452,
#  'garry wilmore': 453,
#  'be prepared to stop': 454,
#  'bcbg': 455,
#  'cellular telephone': 456,
#  'oe188': 457,
#  'clasping': 458,
#  'floss': 459,
#  'braided': 460,
#  'standing on platform': 461,
#  'crystals': 462,
#  'pro tec': 463,
#  "i don't": 464,
#  'beef and peppers': 465,
#  'vent': 466,
#  'later': 467,
#  'pearl': 468,
#  'not much': 469,
#  'do not enter': 470,
#  'pottery store': 471,
#  'orange/yellow plaid': 472,
#  '2:03': 473,
#  'deere': 474,
#  'wta': 475,
#  'on his knee': 476,
#  'skulls': 477,
#  'manchester': 478,
#  'leaving': 479,
#  'sf weekly': 480,
#  'in pen': 481,
#  'smelling wine': 482,
#  'jordan': 483,
#  'beer bottle': 484,
#  'vultures': 485,
#  'actor': 486,
#  "pj's": 487,
#  'schaffhauser platz': 488,
#  "joe's": 489,
#  'glowing': 490,
#  'motorcycle and car': 491,
#  'closer': 492,
#  'bus': 493,
#  'cola': 494,
#  'detour': 495,
#  'feeding giraffes': 496,
#  'rice, meat, vegetables': 497,
#  'hit it': 498,
#  'blackwell': 499,
#  'comfy': 500,
#  'visalia': 501,
#  'around car': 502,
#  'fm11': 503,
#  'girl in yellow dress': 504,
#  'track 1': 505,
#  'qa': 506,
#  'tigo': 507,
#  '12:17': 508,
#  'big beaked': 509,
#  'devil rays': 510,
#  'saturated': 511,
#  'half size': 512,
#  "arby's": 513,
#  'to see giraffe': 514,
#  'ocean kayak': 515,
#  'his and hers': 516,
#  'spider': 517,
#  'pedestrian zone': 518,
#  '80': 519,
#  'firemen': 520,
#  'no clouds': 521,
#  '12:03': 522,
#  'charging': 523,
#  'strawberry and banana': 524,
#  'hollywood blvd': 525,
#  'in trees': 526,
#  'man in jersey': 527,
#  'boys': 528,
#  'damian': 529,
#  'bald': 530,
#  'echo st 6200 n': 531,
#  'swim trunks': 532,
#  '6:52': 533,
#  'worker rights': 534,
#  'carnations': 535,
#  'merry christmas': 536,
#  'blue, yellow and green': 537,
#  '7 eleven': 538,
#  'biodiesel': 539,
#  '65745': 540,
#  'for lease': 541,
#  'laptop': 542,
#  'warning': 543,
#  'pier 30': 544,
#  'at back of photo': 545,
#  'road bike': 546,
#  'rein': 547,
#  'ipod': 548,
#  'above sink': 549,
#  'in front of him': 550,
#  '550': 551,
#  "he's losing": 552,
#  'fanta': 553,
#  'sit': 554,
#  'leather jacket': 555,
#  'weighing': 556,
#  'for': 557,
#  'unanswerable': 558,
#  'black, brown and white': 559,
#  'cardinals': 560,
#  "smucker's": 561,
#  'mosque': 562,
#  'escalator': 563,
#  'afflelou': 564,
#  'on bookcase': 565,
#  'scrunchies': 566,
#  'patient': 567,
#  '1369': 568,
#  'road trip': 569,
#  'bossini': 570,
#  'pay to park': 571,
#  'towel': 572,
#  'behind couch': 573,
#  'oxen': 574,
#  'dogs': 575,
#  'end': 576,
#  'in cage': 577,
#  'gas mask': 578,
#  'she grew it': 579,
#  '8:10': 580,
#  'reays': 581,
#  'banana': 582,
#  'candle': 583,
#  'motta': 584,
#  'crowns': 585,
#  'prius': 586,
#  'on cart': 587,
#  'stand behind': 588,
#  'essay': 589,
#  'to keep it from running away': 590,
#  'below mantle': 591,
#  'n567 jvv': 592,
#  'baa': 593,
#  'fresh berries': 594,
#  'ear of elephant': 595,
#  '1:03': 596,
#  'indian style': 597,
#  'linen': 598,
#  'harvesting': 599,
#  'behind toilet': 600,
#  'ott 98': 601,
#  'looking at camera': 602,
#  'cracker': 603,
#  'yoga mat': 604,
#  'letom': 605,
#  'manners street': 606,
#  'advent': 607,
#  'william': 608,
#  'putting on shoe': 609,
#  '19:11': 610,
#  'cornell': 611,
#  'north': 612,
#  'f': 613,
#  'golf': 614,
#  'dishwasher': 615,
#  'top shelf': 616,
#  'wifi': 617,
#  'fly away': 618,
#  'yard': 619,
#  'pen and glasses': 620,
#  'vintage': 621,
#  'mowing': 622,
#  'you 551': 623,
#  'bearded man': 624,
#  'ytl 434': 625,
#  'not very': 626,
#  'san mateo': 627,
#  'limited visibility': 628,
#  'hard': 629,
#  'behind catcher': 630,
#  'to put out fires': 631,
#  'parking sign': 632,
#  'chris perkins': 633,
#  'howard': 634,
#  'beret': 635,
#  "weiner you've got to be sitting me": 636,
#  'listening to announcer': 637,
#  'storm coming': 638,
#  'yellow blue': 639,
#  'different vehicles': 640,
#  'fsg': 641,
#  'shabby genteel': 642,
#  '9.99': 643,
#  'roman numerals': 644,
#  '1306': 645,
#  'in rows': 646,
#  'satellite dish': 647,
#  'solids': 648,
#  'w center st': 649,
#  'sf weekly free every wednesday': 650,
#  'eb': 651,
#  'bicycle': 652,
#  'bohemiantraveler.com': 653,
#  'by toilet': 654,
#  '2:26': 655,
#  'monitor on': 656,
#  'dog frisbee competition': 657,
#  'sheep barn': 658,
#  'signs': 659,
#  'august 27': 660,
#  'bleach': 661,
#  'behind boy': 662,
#  'cannot tell': 663,
#  'less': 664,
#  'nonstick': 665,
#  'truck bed': 666,
#  'no text': 667,
#  'extra cheese': 668,
#  'heat food': 669,
#  'cairn': 670,
#  'crowded': 671,
#  'anza': 672,
#  'nationals': 673,
#  'landed': 674,
#  'ipad, laptop, and cell phone': 675,
#  'hanging on oven': 676,
#  'slower': 677,
#  'wedge': 678,
#  'not high': 679,
#  'faconnable': 680,
#  'mango': 681,
#  'staring': 682,
#  'no belt': 683,
#  'visilab': 684,
#  'china': 685,
#  'gt': 686,
#  'bulls': 687,
#  'last week': 688,
#  'brabantliner': 689,
#  'bicycle tires': 690,
#  'union pacific': 691,
#  'colin': 692,
#  '4:32': 693,
#  '5pm': 694,
#  'scratches': 695,
#  'soccer balls': 696,
#  'willard': 697,
#  'raffaello': 698,
#  'holding umbrella': 699,
#  'handshake': 700,
#  'santa hats': 701,
#  'phone and lighter': 702,
#  'maze': 703,
#  'steak sauce': 704,
#  'albert s samuels co': 705,
#  'flip flops': 706,
#  '4:04': 707,
#  'bellhop': 708,
#  'looking at horses': 709,
#  'nokia': 710,
#  '1st person': 711,
#  'yorkie': 712,
#  'palm trees, surfboards, banner': 713,
#  'to watch game': 714,
#  '1:41': 715,
#  'countertops': 716,
#  'kmb': 717,
#  'lion and hedgehog': 718,
#  'motorcycle racing': 719,
#  'under leg': 720,
#  'quail': 721,
#  'lily pads': 722,
#  '2990': 723,
#  'rocking': 724,
#  'recreation': 725,
#  'mixed': 726,
#  'lollipop': 727,
#  'african': 728,
#  'bird feeder': 729,
#  '150': 730,
#  'no bag': 731,
#  'measuring distance': 732,
#  'on them': 733,
#  'dyed it': 734,
#  'daffodils': 735,
#  'f-150': 736,
#  'stop and one way': 737,
#  'rod': 738,
#  'rt': 739,
#  'baseball cap': 740,
#  'new orleans': 741,
#  'pen': 742,
#  'resident evil': 743,
#  'grow': 744,
#  'sneaker': 745,
#  '3:15': 746,
#  'top ramen': 747,
#  'white, brown, black': 748,
#  'apple, banana, pomegranate': 749,
#  'buggy': 750,
#  '7577': 751,
#  'for display': 752,
#  'other dog': 753,
#  'iced coffee': 754,
#  'plug': 755,
#  'adams': 756,
#  'neither': 757,
#  'sleeping bag': 758,
#  'cafeteria': 759,
#  'chained': 760,
#  'festival': 761,
#  '631': 762,
#  'sewing': 763,
#  'boots and umbrella': 764,
#  'easter': 765,
#  'bed': 766,
#  'spa': 767,
#  '987': 768,
#  'passenger train station': 769,
#  '100 feet': 770,
#  'longhorns': 771,
#  '296': 772,
#  'books': 773,
#  'ferris wheel': 774,
#  "women's": 775,
#  'strapless': 776,
#  '11:33': 777,
#  'vehicle': 778,
#  'chess piece': 779,
#  'its out for trash': 780,
#  'nashville': 781,
#  'zero': 782,
#  '2:05': 783,
#  'wtatennis.com': 784,
#  '6"': 785,
#  'other man': 786,
#  'ywl 45v': 787,
#  'calvin klein': 788,
#  'no letters': 789,
#  'britvic': 790,
#  'peace sign': 791,
#  '3:48': 792,
#  'showing videos': 793,
#  '2:39': 794,
#  'manly': 795,
#  '402b': 796,
#  '24"': 797,
#  'john d': 798,
#  'cooking': 799,
#  'purple, yellow, white, brown, green, red, orange, yellow, blue': 800,
#  'kia': 801,
#  'between glass': 802,
#  'they are decorated': 803,
#  '650dye': 804,
#  'on top of toilet': 805,
#  '70677': 806,
#  'dreadlocks': 807,
#  'bumper': 808,
#  '9:17': 809,
#  'blue angels': 810,
#  'city coach': 811,
#  'yard sale': 812,
#  'eldest': 813,
#  'mount pleasant rd': 814,
#  'ficus': 815,
#  'whiskey': 816,
#  'column': 817,
#  'nightfall': 818,
#  'latin': 819,
#  'white, black, red': 820,
#  'paddle boat': 821,
#  'john b clarke': 822,
#  'squat': 823,
#  'patch': 824,
#  "it's time to siena": 825,
#  'shades': 826,
#  'behind man to left': 827,
#  'pointy': 828,
#  'hills': 829,
#  'ikea': 830,
#  'nasa ames': 831,
#  'northumbria': 832,
#  'aegon': 833,
#  'basket': 834,
#  'boy on right': 835,
#  '1:05': 836,
#  'bridgestone': 837,
#  'point': 838,
#  'tractor trailer': 839,
#  'overpass': 840,
#  'wallpaper': 841,
#  'on rock': 842,
#  'ones fighter jet': 843,
#  'holding umbrellas': 844,
#  'it is paved': 845,
#  'watching presentation': 846,
#  'nervous': 847,
#  'vapor': 848,
#  'bryn mawr': 849,
#  '4:49': 850,
#  'competing': 851,
#  'cruise ship': 852,
#  'veterinarian': 853,
#  'ukrsibbank': 854,
#  'fruit and cheese': 855,
#  '1:08': 856,
#  'tank top and shorts': 857,
#  'nottingham': 858,
#  '1998': 859,
#  'curtain': 860,
#  'hickory dickory dock': 861,
#  'fishnet': 862,
#  'catnip': 863,
#  'bunches': 864,
#  'next to wall': 865,
#  'ap': 866,
#  'pepsi cola': 867,
#  'dress shirt': 868,
#  'mavic': 869,
#  'very clear': 870,
#  '554': 871,
#  '44019': 872,
#  'tile': 873,
#  'play games': 874,
#  'guiding horse': 875,
#  'chair': 876,
#  'circular': 877,
#  'talk': 878,
#  'pepperoni': 879,
#  "he can't walk": 880,
#  'hot dog and fries': 881,
#  'us open': 882,
#  'avocado': 883,
#  'reins': 884,
#  'palomino': 885,
#  'right hand': 886,
#  'not busy': 887,
#  'face': 888,
#  'attic': 889,
#  'turnover': 890,
#  'bowls': 891,
#  'no closet': 892,
#  'west union': 893,
#  'west coast air': 894,
#  'electric vehicle parking only while charging': 895,
#  'second from left': 896,
#  'shoulders': 897,
#  'handmade nation': 898,
#  'under pillow': 899,
#  'placemats': 900,
#  'speed rabbit pizza': 901,
#  'no smoking sign': 902,
#  'in front of boxes': 903,
#  'puddles': 904,
#  'pj 2009': 905,
#  'cauliflower and broccoli': 906,
#  'easel': 907,
#  'cardinal male': 908,
#  '$10': 909,
#  'in hand': 910,
#  'eye protection': 911,
#  'charlotte': 912,
#  "ray's tavern": 913,
#  '39, 1': 914,
#  'they are fried': 915,
#  'bent': 916,
#  'mini golf': 917,
#  'on vase': 918,
#  'zombie': 919,
#  'macaroni salad': 920,
#  'thermostat': 921,
#  '200 feet': 922,
#  'legs crossed': 923,
#  'shipyard': 924,
#  'houseboats': 925,
#  'chair, wii remote, tv remotes': 926,
#  'wednesday': 927,
#  'watching ocean': 928,
#  'cubs': 929,
#  'portrait': 930,
#  'lower manhattan': 931,
#  'leftmost': 932,
#  'bundt': 933,
#  'atlantic': 934,
#  'very long': 935,
#  'desk job': 936,
#  'by wall': 937,
#  'lifeguard stand': 938,
#  'in water': 939,
#  'ariel': 940,
#  'swinging bat': 941,
#  '2:55': 942,
#  'to food': 943,
#  'sitting in bowl': 944,
#  '1406': 945,
#  'rocking chair': 946,
#  'bikini': 947,
#  'in his hands': 948,
#  'tomato, cheese, onion': 949,
#  'dsb': 950,
#  'end of school': 951,
#  'it is dark out': 952,
#  'children love them': 953,
#  'mitt': 954,
#  '4:35': 955,
#  'pete rose': 956,
#  'pure white': 957,
#  'brazil': 958,
#  'trim': 959,
#  '4 to 5': 960,
#  'troll': 961,
#  'street names': 962,
#  'horses, cows': 963,
#  'getting her hair done': 964,
#  '7:00': 965,
#  'mat': 966,
#  'waiting to hit': 967,
#  'lorac': 968,
#  'stop think observe proceed': 969,
#  'chiclets': 970,
#  'next to fire hydrant': 971,
#  'prof verbernelaan': 972,
#  'last': 973,
#  'c92678m': 974,
#  'apartment': 975,
#  'geico': 976,
#  'brewer': 977,
#  'oregon': 978,
#  'purple and green': 979,
#  "chef's": 980,
#  'baseballs': 981,
#  'blue plaid': 982,
#  'dockers': 983,
#  'pillars': 984,
#  'seat cover': 985,
#  'medemblik bus station': 986,
#  'shaking camera': 987,
#  'shingles': 988,
#  'white shirt': 989,
#  'baseball bats': 990,
#  'in forest': 991,
#  'white yellow pink purple and blue': 992,
#  'sortie': 993,
#  'wet grass': 994,
#  'junkyard': 995,
#  '44': 996,
#  'lawn': 997,
#  'bear and wolf museum': 998,
#  'selfie stick': 999,
#  ...}

# %% [markdown]
# #### empty some memory to prevent memory overflow

# %%
del labels
del label_map
# del answers_tokenizer
del answer_word_index
del padded_answers
del answers

# %% [markdown]
# #### shape of the dataset

# %%
print(len(features_id))
print(padded_sequences.shape)
print(one_hot_answers.shape)
# Out:
# 214354
# (214354, 30)
# (214354, 14008)

# %% [markdown]
# ### split train into 70% train and 30% test
# #### (inplace to prevent memory overflow)

# %%
split_indices = np.random.randint(low=0, high=len(features_id), size=int(len(features_id)*0.3))
split_indices = sorted(split_indices,reverse=True)

# %%
test_padded_sequences = []
padded_sequences = list(padded_sequences)
for i in split_indices:
    test_padded_sequences.append(padded_sequences.pop(i))

# %%
test_one_hot_answers = []
one_hot_answers = list(one_hot_answers)
for i in split_indices:
    test_one_hot_answers.append(one_hot_answers.pop(i))

# %%
test_features_id = []
for i in split_indices:
    test_features_id.append(features_id.pop(i))

# %% [markdown]
# ### split 30% test into 20% test and 10% validate
# #### (inplace to prevent memory overflow)

# %%
split_indices = np.random.randint(low=0, high=len(test_features_id), size=int(len(test_features_id)*0.3))
split_indices = sorted(split_indices,reverse=True)

# %%
val_padded_sequences = []
for i in split_indices:
    val_padded_sequences.append(test_padded_sequences.pop(i))

# %%
val_one_hot_answers = []
for i in split_indices:
    val_one_hot_answers.append(test_one_hot_answers.pop(i))

# %%
val_features_id = []
for i in split_indices:
    val_features_id.append(test_features_id.pop(i))

# %% [markdown]
# #### first model: LSTM for Questions and concat with inception v3 output
# ##### uses SGD with momentum optimizer

# %%
# Define the input layers
question_input = Input(shape=(max_question_length, ), name='question_input')
image_input = Input(shape=(25088, ), name='image_input')

# Define the embedding layer for the questions
question_embedding = Embedding(input_dim=len(word_index)+1, output_dim=300, input_length=max_question_length,
                               name='question_embedding')(question_input)

# Define the LSTM layer for the questions
question_lstm = LSTM(units=512, name='question_lstm', return_sequences=True)(question_embedding)
question_lstm = Dropout(0.3, name='question_dropout')(question_lstm)

question_lstm2 = LSTM(units=256, name='question_lstm2')(question_lstm)
question_lstm2 = Dropout(0.2, name='question_dropout2')(question_lstm2)

# Define the dense layer for the image features
image_dense = Dense(units=256, activation='relu', name='image_dense')(image_input)
image_dense = Dropout(0.2, name='image_dropout')(image_dense)

# Concatenate the output from the LSTM and dense layers
concatenated = concatenate([question_lstm2, image_dense], name='concatenated')

dense_cnc = Dense(units=512, activation='relu', name='dens_conc')(concatenated)
dense_cnc2 = Dense(units=512, activation='relu', name='dens_conc2')(dense_cnc)
# Define the output layer for the classification
output = Dense(units=len(unique_answers), activation='softmax', name='output')(dense_cnc2)

# Define the model
model = Model(inputs=[question_input, image_input], outputs=output)
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.001, momentum=0.9), metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  question_input (InputLayer  [(None, 30)]                 0         []
#  )
#
#  question_embedding (Embedd  (None, 30, 300)              3182100   ['question_input[0][0]']
#  ing)
#
#  question_lstm (LSTM)        (None, 30, 512)              1665024   ['question_embedding[0][0]']
#
#  question_dropout (Dropout)  (None, 30, 512)              0         ['question_lstm[0][0]']
#
#  image_input (InputLayer)    [(None, 25088)]              0         []
#
#  question_lstm2 (LSTM)       (None, 256)                  787456    ['question_dropout[0][0]']
#
#  image_dense (Dense)         (None, 256)                  6422784   ['image_input[0][0]']
#
#  question_dropout2 (Dropout  (None, 256)                  0         ['question_lstm2[0][0]']
#  )
#
#  image_dropout (Dropout)     (None, 256)                  0         ['image_dense[0][0]']
#
#  concatenated (Concatenate)  (None, 512)                  0         ['question_dropout2[0][0]',
#                                                                      'image_dropout[0][0]']
#
#  dens_conc (Dense)           (None, 512)                  262656    ['concatenated[0][0]']
#
#  dens_conc2 (Dense)          (None, 512)                  262656    ['dens_conc[0][0]']
#
#  output (Dense)              (None, 14008)                7186104   ['dens_conc2[0][0]']
#
# ==================================================================================================
# Total params: 19768780 (75.41 MB)
# Trainable params: 19768780 (75.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# #### creating a custom generator

# %%
def data_generator(image_features, padded_questions, labels, batch_size):
    num_samples = len(labels)
    steps_per_epoch = num_samples // batch_size
    while True:
        for i in range(steps_per_epoch):
            batch_image_features = []
            for j in  image_features[i*batch_size:(i+1)*batch_size]:
                batch_image_features.append(train_imgs_features[j])
            batch_padded_questions = padded_questions[i*batch_size:(i+1)*batch_size]
            batch_labels = labels[i*batch_size:(i+1)*batch_size]
            yield [np.asarray(batch_padded_questions), np.asarray(batch_image_features)], np.asarray(batch_labels)

# %% [markdown]
# #### training the model using 70% train and 10% validate

# %%
batch_size = 128
steps_per_epoch = len(one_hot_answers) // batch_size
model.fit(data_generator(features_id,padded_sequences,one_hot_answers,batch_size),
          steps_per_epoch=steps_per_epoch,
          epochs=10,
         validation_data = data_generator(val_features_id,val_padded_sequences,val_one_hot_answers,batch_size),
         validation_steps = int(len(val_features_id)/batch_size))
# Out:
# Epoch 1/10
# 1172/1172 [==============================] - 343s 290ms/step - loss: 5.9812 - accuracy: 0.1812 - val_loss: 5.4328 - val_accuracy: 0.1872
# Epoch 2/10
# 1172/1172 [==============================] - 338s 288ms/step - loss: 5.3689 - accuracy: 0.1866 - val_loss: 5.3038 - val_accuracy: 0.1896
# Epoch 3/10
# 1172/1172 [==============================] - 339s 290ms/step - loss: 5.2146 - accuracy: 0.1858 - val_loss: 5.1355 - val_accuracy: 0.1913
# Epoch 4/10
# 1172/1172 [==============================] - 337s 288ms/step - loss: 5.0876 - accuracy: 0.1879 - val_loss: 5.0574 - val_accuracy: 0.1909
# Epoch 5/10
# 1172/1172 [==============================] - 339s 289ms/step - loss: 5.0102 - accuracy: 0.1874 - val_loss: 5.0007 - val_accuracy: 0.1896
# Epoch 6/10
# 1172/1172 [==============================] - 338s 288ms/step - loss: 5.1116 - accuracy: 0.1868 - val_loss: 5.0603 - val_accuracy: 0.1863
# Epoch 7/10
# 1172/1172 [==============================] - 338s 288ms/step - loss: 5.0619 - accuracy: 0.1879 - val_loss: 5.0965 - val_accuracy: 0.1878
# Epoch 8/10
# 1172/1172 [==============================] - 339s 289ms/step - loss: 5.0617 - accuracy: 0.1865 - val_loss: 5.0368 - val_accuracy: 0.1891
# Epoch 9/10
# 1172/1172 [==============================] - 339s 289ms/step - loss: 5.0302 - accuracy: 0.1880 - val_loss: 5.0426 - val_accuracy: 0.1887
# Epoch 10/10
# 1172/1172 [==============================] - 338s 288ms/step - loss: 5.0018 - accuracy: 0.1884 - val_loss: 5.0469 - val_accuracy: 0.1898

# %% [markdown]
# #### saving the model

# %%
model.save("VGG19_LSTM_SGD.h5")
# Out:
# /home/diamo/VAQ/vaq/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### end
